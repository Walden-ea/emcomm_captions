# %%
from datasets import load_from_disk
import torch
import numpy as np
import pandas as pd

# %%
original_3_ds = load_from_disk("/home/elena/emcomm/emcomm_captions/checkpoints/3_distractors_proper/messages/coco_val_message_captions_3_distractors")
original_5_ds = load_from_disk("/home/elena/emcomm/emcomm_captions/checkpoints/5_distractors_proper/messages/coco_val_message_captions_5_distractors")
curr_best_3_ds = load_from_disk("//home/elena/emcomm/emcomm_captions/checkpoints/3_d_proper_sim_based_datasets_default_annealing/messages/coco_val_message_captions_3_distractors")
curr_42_epoch_3_ds = load_from_disk("/home/elena/emcomm/emcomm_captions/checkpoints/3_d_proper_sim_based_datasets_slow_annealing_data_last_checkpoint/messages/coco_val_message_captions_3_distractors")

# %%
datasets = {
    "original_3_ds": original_3_ds,
    "original_5_ds": original_5_ds,
    "curr_best_3_ds": curr_best_3_ds,
    "curr_42_epoch_3_ds": curr_42_epoch_3_ds
}

# %%
for i in range(5):
    for name, ds in datasets.items():
        print(f"{name}: ")
        print(ds[i]['captions'])
        print(ds[i]['message'])
        print(ds[i]['message_truncated'])
        print('\n')
# Out:
# original_3_ds:
# ['A man is in a kitchen making pizzas.', 'Man in apron standing on front of oven with pans and bakeware', 'A baker is working in the kitchen rolling dough.', 'A person standing by a stove in a kitchen.', 'A table with pies being made and a person standing near a wall with pots and pans hanging on the wall.']
# [26, 57, 60, 27, 0, 57, 24, 57, 0, 0, 57, 57, 64, 0, 24, 57, 64, 0, 60, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 0]
# [26, 57, 60, 27]
#
#
# original_5_ds:
# ['A man is in a kitchen making pizzas.', 'Man in apron standing on front of oven with pans and bakeware', 'A baker is working in the kitchen rolling dough.', 'A person standing by a stove in a kitchen.', 'A table with pies being made and a person standing near a wall with pots and pans hanging on the wall.']
# [68, 29, 45, 0, 1, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 0]
# [68, 29, 45]
#
#
# curr_best_3_ds:
# ['A man is in a kitchen making pizzas.', 'Man in apron standing on front of oven with pans and bakeware', 'A baker is working in the kitchen rolling dough.', 'A person standing by a stove in a kitchen.', 'A table with pies being made and a person standing near a wall with pots and pans hanging on the wall.']
# [58, 36, 0, 66, 66, 0, 66, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 0, 0, 0, 66, 66, 66, 66, 0, 0, 66, 66, 66, 66, 66, 66, 0, 66, 66, 66, 66, 0, 66, 66, 66, 66, 66, 66, 66, 66, 53, 66, 66, 0, 0, 66, 66, 66, 66, 66, 66, 66, 0, 0, 66, 0, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 0, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 0, 66, 0]
# [58, 36]
#
#
# curr_42_epoch_3_ds:
# ['A man is in a kitchen making pizzas.', 'Man in apron standing on front of oven with pans and bakeware', 'A baker is working in the kitchen rolling dough.', 'A person standing by a stove in a kitchen.', 'A table with pies being made and a person standing near a wall with pots and pans hanging on the wall.']
# [45, 50, 0, 0, 58, 0, 58, 0, 0, 58, 0, 58, 59, 45, 58, 0, 0, 0, 0, 0, 58, 58, 58, 58, 0, 0, 0, 58, 0, 0, 6, 0, 0, 0, 58, 48, 58, 59, 45, 58, 0, 58, 0, 0, 0, 58, 45, 58, 0, 0, 0, 58, 0, 0, 0, 58, 35, 58, 0, 0, 58, 0, 0, 58, 35, 58, 0, 0, 0, 0, 0, 0, 58, 48, 62, 0, 0, 0, 58, 0, 0, 0, 0, 0, 58, 58, 58, 0, 0, 0, 0, 0, 58, 58, 58, 45, 61, 58, 58, 45, 0]
# [45, 50]
#
#
# original_3_ds:
# ['The dining table near the kitchen has a bowl of fruit on it.', 'A small kitchen has various appliances and a table.', 'The kitchen is clean and ready for us to see.', 'A kitchen and dining area decorated in white.', 'A kitchen that has a bowl of fruit on the table.']
# [26, 57, 60, 64, 0, 57, 57, 64, 0, 68, 57, 64, 0, 60, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0]
# [26, 57, 60, 64]
#
#
# original_5_ds:
# ['The dining table near the kitchen has a bowl of fruit on it.', 'A small kitchen has various appliances and a table.', 'The kitchen is clean and ready for us to see.', 'A kitchen and dining area decorated in white.', 'A kitchen that has a bowl of fruit on the table.']
# [68, 59, 45, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 0]
# [68, 59, 45]
#
#
# curr_best_3_ds:
# ['The dining table near the kitchen has a bowl of fruit on it.', 'A small kitchen has various appliances and a table.', 'The kitchen is clean and ready for us to see.', 'A kitchen and dining area decorated in white.', 'A kitchen that has a bowl of fruit on the table.']
# [48, 33, 0, 0, 66, 66, 67, 37, 0, 66, 0, 66, 66, 0, 66, 0, 66, 0, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 0, 0, 66, 66, 0, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 53, 66, 0, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 3, 66, 53, 66, 0, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 0, 0, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 0, 0, 0, 66, 66, 66, 66, 66, 66, 0]
# [48, 33]
#
#
# curr_42_epoch_3_ds:
# ['The dining table near the kitchen has a bowl of fruit on it.', 'A small kitchen has various appliances and a table.', 'The kitchen is clean and ready for us to see.', 'A kitchen and dining area decorated in white.', 'A kitchen that has a bowl of fruit on the table.']
# [45, 47, 0, 0, 0, 58, 0, 58, 0, 0, 0, 0, 35, 58, 0, 0, 0, 0, 0, 58, 0, 58, 59, 45, 58, 0, 0, 0, 0, 0, 0, 58, 58, 62, 0, 0, 0, 0, 58, 58, 58, 0, 0, 58, 0, 58, 58, 0, 0, 0, 58, 45, 62, 0, 0, 0, 0, 58, 45, 62, 0, 0, 0, 0, 58, 45, 62, 0, 0, 0, 0, 58, 45, 62, 0, 0, 0, 0, 58, 45, 62, 0, 0, 0, 0, 58, 45, 62, 0, 0, 0, 0, 58, 45, 62, 0, 0, 0, 0, 58, 0]
# [45, 47]
#
#
# original_3_ds:
# ['a person with a shopping cart on a city street ', 'City dwellers walk by as a homeless man begs for cash.', 'People walking past a homeless man begging on a city street', 'a homeless man holding a cup and standing next to a shopping cart on a street', 'People are walking on the street by a homeless person.']
# [60, 15, 0, 57, 57, 15, 0, 68, 57, 15, 0, 24, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 0]
# [60, 15]
#
#
# original_5_ds:
# ['a person with a shopping cart on a city street ', 'City dwellers walk by as a homeless man begs for cash.', 'People walking past a homeless man begging on a city street', 'a homeless man holding a cup and standing next to a shopping cart on a street', 'People are walking on the street by a homeless person.']
# [68, 11, 1, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 0]
# [68, 11, 1]
#
#
# curr_best_3_ds:
# ['a person with a shopping cart on a city street ', 'City dwellers walk by as a homeless man begs for cash.', 'People walking past a homeless man begging on a city street', 'a homeless man holding a cup and standing next to a shopping cart on a street', 'People are walking on the street by a homeless person.']
# [53, 3, 38, 0, 66, 53, 0, 66, 0, 0, 66, 0, 0, 66, 0, 66, 66, 66, 66, 66, 66, 66, 66, 45, 66, 0, 0, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 53, 66, 66, 0, 0, 66, 66, 66, 66, 45, 66, 0, 0, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 0, 0, 66, 66, 66, 66, 53, 66, 0, 0, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 0, 0, 66, 66, 29, 66, 0, 0, 66, 66, 66, 66, 66, 0]
# [53, 3, 38]
#
#
# curr_42_epoch_3_ds:
# ['a person with a shopping cart on a city street ', 'City dwellers walk by as a homeless man begs for cash.', 'People walking past a homeless man begging on a city street', 'a homeless man holding a cup and standing next to a shopping cart on a street', 'People are walking on the street by a homeless person.']
# [29, 50, 0, 58, 0, 58, 0, 0, 0, 0, 58, 58, 0, 0, 0, 0, 58, 0, 0, 0, 0, 58, 0, 58, 59, 45, 58, 0, 0, 0, 0, 0, 0, 58, 58, 62, 0, 58, 0, 58, 58, 0, 58, 0, 47, 0, 0, 0, 0, 0, 58, 0, 0, 58, 0, 58, 58, 0, 58, 0, 58, 0, 0, 0, 0, 0, 58, 0, 58, 0, 0, 58, 0, 58, 58, 0, 0, 0, 0, 58, 0, 0, 0, 0, 0, 58, 58, 3, 0, 0, 0, 58, 0, 58, 58, 0, 0, 58, 0, 58, 0]
# [29, 50]
#
#
# original_3_ds:
# ['A person on a skateboard and bike at a skate park.', 'A man on a skateboard performs a trick at the skate park', 'A skateboarder jumps into the air as he performs a skateboard trick.', 'Athletes performing tricks on a BMX bicycle and a skateboard.', 'a man falls off his skateboard in a skate park.']
# [60, 15, 0, 68, 57, 15, 0, 68, 57, 57, 64, 0, 57, 57, 64, 0, 24, 57, 64, 0, 60, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 0]
# [60, 15]
#
#
# original_5_ds:
# ['A person on a skateboard and bike at a skate park.', 'A man on a skateboard performs a trick at the skate park', 'A skateboarder jumps into the air as he performs a skateboard trick.', 'Athletes performing tricks on a BMX bicycle and a skateboard.', 'a man falls off his skateboard in a skate park.']
# [45, 11, 48, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 0]
# [45, 11, 48]
#
#
# curr_best_3_ds:
# ['A person on a skateboard and bike at a skate park.', 'A man on a skateboard performs a trick at the skate park', 'A skateboarder jumps into the air as he performs a skateboard trick.', 'Athletes performing tricks on a BMX bicycle and a skateboard.', 'a man falls off his skateboard in a skate park.']
# [10, 47, 38, 0, 0, 66, 66, 66, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 0, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 0, 0, 66, 66, 66, 0, 0, 66, 66, 66, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 53, 66, 66, 0, 0, 66, 66, 66, 66, 53, 66, 0, 0, 66, 0, 66, 66, 0, 66, 66, 66, 66, 66, 66, 66, 53, 66, 66, 0, 0, 0]
# [10, 47, 38]
#
#
# curr_42_epoch_3_ds:
# ['A person on a skateboard and bike at a skate park.', 'A man on a skateboard performs a trick at the skate park', 'A skateboarder jumps into the air as he performs a skateboard trick.', 'Athletes performing tricks on a BMX bicycle and a skateboard.', 'a man falls off his skateboard in a skate park.']
# [29, 3, 0, 58, 0, 58, 0, 0, 58, 0, 58, 59, 61, 58, 0, 0, 0, 0, 0, 58, 58, 62, 0, 6, 0, 58, 0, 0, 0, 0, 0, 58, 58, 62, 0, 0, 0, 58, 0, 58, 0, 0, 0, 58, 58, 58, 0, 0, 0, 0, 0, 0, 58, 58, 58, 45, 61, 58, 58, 0, 0, 0, 0, 0, 58, 45, 62, 0, 0, 0, 0, 58, 0, 58, 0, 0, 0, 0, 0, 58, 58, 62, 0, 0, 0, 0, 0, 35, 58, 0, 0, 0, 0, 58, 58, 0, 0, 58, 35, 58, 0]
# [29, 3]
#
#
# original_3_ds:
# ['a blue bike parked on a side walk ', 'A bicycle is chained to a fixture on a city street', 'A blue bicycle sits on a sidewalk near a street.', 'A bicycle is locked up to a post', 'a bike sits parked next to a street ']
# [37, 15, 0, 57, 57, 64, 0, 60, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 57, 64, 0, 68, 57, 15, 0, 68, 0]
# [37, 15]
#
#
# original_5_ds:
# ['a blue bike parked on a side walk ', 'A bicycle is chained to a fixture on a city street', 'A blue bicycle sits on a sidewalk near a street.', 'A bicycle is locked up to a post', 'a bike sits parked next to a street ']
# [8, 0, 1, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 43, 0, 0]
# [8]
#
#
# curr_best_3_ds:
# ['a blue bike parked on a side walk ', 'A bicycle is chained to a fixture on a city street', 'A blue bicycle sits on a sidewalk near a street.', 'A bicycle is locked up to a post', 'a bike sits parked next to a street ']
# [49, 66, 37, 0, 66, 0, 66, 66, 0, 0, 66, 66, 66, 66, 0, 66, 66, 66, 66, 66, 53, 66, 66, 0, 0, 0, 0, 66, 66, 66, 66, 66, 66, 66, 53, 66, 66, 0, 0, 0, 0, 66, 66, 66, 66, 66, 66, 66, 53, 66, 66, 0, 0, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 66, 0, 0, 66, 66, 66, 0, 0, 66, 66, 66, 66, 0, 66, 0, 0, 66, 66, 66, 66, 66, 66, 66, 0, 66, 66, 0, 0, 0, 66, 66, 66, 66, 66, 66, 66, 66, 0]
# [49, 66, 37]
#
#
# curr_42_epoch_3_ds:
# ['a blue bike parked on a side walk ', 'A bicycle is chained to a fixture on a city street', 'A blue bicycle sits on a sidewalk near a street.', 'A bicycle is locked up to a post', 'a bike sits parked next to a street ']
# [18, 50, 0, 58, 0, 58, 59, 45, 58, 0, 58, 0, 0, 0, 0, 58, 58, 0, 6, 0, 0, 0, 58, 0, 58, 0, 0, 0, 0, 0, 58, 58, 58, 0, 6, 0, 58, 0, 0, 58, 0, 58, 59, 45, 58, 0, 0, 0, 0, 58, 0, 58, 58, 0, 0, 0, 0, 58, 58, 58, 0, 6, 0, 0, 0, 0, 0, 58, 58, 62, 0, 0, 0, 58, 0, 58, 0, 0, 0, 58, 0, 58, 0, 0, 58, 0, 0, 0, 0, 58, 58, 0, 0, 58, 0, 35, 58, 0, 58, 0, 0]
# [18, 50]
